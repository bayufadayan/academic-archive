# %%
import numpy as np
import pandas as pd

# %%
alternatif = ["Paijo", 'Paiman', 'Paino']

# %%
diag=1
C1_C2 = 3
C1_C3 = 8
C2_C3 = 3

C1_C2_Inv = 1/C1_C2
C1_C3_Inv = 1/C1_C3
C2_C3_Inv = 1/C2_C3

# %%
matric_inisial = {
    'Tanggung Jawab':{
        'Tanggung Jawab':diag,
        'Jujur':C1_C2,
        'Disiplin':C1_C3
    },
    'Jujur':{
        'Tanggung Jawab':C1_C2_Inv,
        'Jujur':diag,
        'Disiplin':C2_C3
    },
    'Disiplin':{
        'Tanggung Jawab':C1_C3_Inv,
        'Jujur':C2_C3_Inv,
        'Disiplin':diag
    }
}

# %%
ahp_step1 = pd.DataFrame(matric_inisial)

# %%
ahp_step1 =  ahp_step1.T

# %%
ahp_step1
# Out:
#                 Tanggung Jawab     Jujur  Disiplin
# Tanggung Jawab        1.000000  3.000000       8.0
# Jujur                 0.333333  1.000000       3.0
# Disiplin              0.125000  0.333333       1.0

# %%
ahp_step1_a = ahp_step1.sum()

# %%
ahp_step1_a
# Out:
# Tanggung Jawab     1.458333
# Jujur              4.333333
# Disiplin          12.000000
# dtype: float64

# %%
ahp_step1_a = pd.DataFrame(ahp_step1_a)

# %%
ahp_step1_a = ahp_step1_a.T

# %%
ahp_step1_a
# Out:
#    Tanggung Jawab     Jujur  Disiplin
# 0        1.458333  4.333333      12.0

# %%
ahp_step1_b = ahp_step1.div(ahp_step1_a.iloc[0])

# %%
ahp_step1_b = ahp_step1_b

# %%
ahp_step1_b
# Out:
#                 Tanggung Jawab     Jujur  Disiplin
# Tanggung Jawab        0.685714  0.692308  0.666667
# Jujur                 0.228571  0.230769  0.250000
# Disiplin              0.085714  0.076923  0.083333

# %%
ahp_step1_c = ahp_step1_b.mean(axis=1)

# %%
ahp_step1_c = pd.DataFrame(ahp_step1_c)

# %%
ahp_step1_c = ahp_step1_c.T

# %%
ahp_step1_c
# Out:
#    Tanggung Jawab     Jujur  Disiplin
# 0        0.681563  0.236447   0.08199

# %% [markdown]
# Lambda Max

# %%
lambda_max = (ahp_step1_a * ahp_step1_c)

# %%
lambda_max
# Out:
#    Tanggung Jawab     Jujur  Disiplin
# 0        0.993946  1.024603  0.983883

# %%
lambda_max = lambda_max.sum(axis = 1)

# %%
lambda_max
# Out:
# 0    3.002432
# dtype: float64

# %%
CI = (lambda_max-3)/(3-1)

# %%
CI
# Out:
# 0    0.001216
# dtype: float64

# %%
CR = CI/0.58

# %%
CR
# Out:
# 0    0.002096
# dtype: float64
